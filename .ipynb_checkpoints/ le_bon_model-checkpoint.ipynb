# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score
import datetime
from geopy import distance

# %%
Train = pd.read_csv("Train.csv")
Test = pd.read_csv("Test.csv")
Rider = pd.read_csv("Riders.csv")
sp = pd.read_csv("SampleSubmission.csv")

# %%
# ORS
ors_test = pd.read_csv("ors_test.csv")
ors_train = pd.read_csv("ors_train.csv")

# %%
print(ors_test.shape)
print(ors_train.shape)
# Out:
# (7068, 2)
# (21201, 2)

# %%
ors_train.columns
# Out:
# Index(['distance', 'duration'], dtype='object')

# %%
Train["distance_ors"] = ors_train["distance"]/1000  # en mètre / sec
Test["distance_ors"] = ors_test["distance"]/1000
Train["duration_ors"] = ors_train["duration"]  # sec
Test["duration_ors"] = ors_test["duration"]
Train = pd.merge(Train, Rider, how='left', left_on='Rider Id', right_on='Rider Id', left_index=True)
Test = pd.merge(Test, Rider, how='left', left_on='Rider Id', right_on='Rider Id', left_index=True)

# %%
col_x = ["Platform Type","Personal or Business","Pickup Long","Pickup Lat","Destination Long","Destination Lat","Distance (KM)","Temperature","Precipitation in millimeters","Pickup - Weekday (Mo = 1)","Pickup - Time","No_Of_Orders","Age","Average_Rating","duration_ors","distance_ors"]
col_x = sorted(col_x)
col_y = ["Time from Pickup to Arrival"]
Train = Train[col_x+col_y]
Test = Test[col_x]

# %%
def convert_time24(nom,col,data=Train):
 tab = []
 for i in col:
   s = i.split()
   terminaison = s[1]
   if terminaison == "PM":
     time = s[0].split(":")
     time = (int(time[0]) + 12) * 3600 + int(time[1]) * 60 + int(time[2])
     tab.append(time)
   else:
     time = s[0].split(":")
     time = (int(time[0]) + 12) * 3600 + int(time[1]) * 60 + int(time[2])
     tab.append(time)
 data[nom] = tab
 return True
 # Train
#convert_time24("Placement - Time",Train["Placement - Time"])
#convert_time24("Confirmation - Time",Train["Confirmation - Time"])
#convert_time24("Pickup - Time",Train["Pickup - Time"])
#Test
#convert_time24("Placement - Time",Test["Placement - Time"],Test)
#convert_time24("Confirmation - Time",Test["Confirmation - Time"],Test)
#convert_time24("Pickup - Time",Test["Pickup - Time"],Test)

# %%
Train['Temperature'] = Train['Temperature'].fillna(Train['Temperature'].mean())
Test['Temperature'] = Test['Temperature'].fillna(Test['Temperature'].mean())
Train['Precipitation in millimeters'] = Train['Precipitation in millimeters'].fillna(0)
Test['Precipitation in millimeters'] = Test['Precipitation in millimeters'].fillna(0)

# %%
def heure(data):
 time=[]
 data = pd.to_datetime(data)
 for i in data:
     i = i.time()
     ti = (str(i).split(':')[0])
     time.append(int(ti))
 time
 data = time
 return data

# %%
print(heure(Train ['Pickup - Time']))
# Out:
# [10, 11, 12, 9, 10, 15, 9, 14, 12, 17, 10, 16, 15, 9, 10, 13, 12, 12, 11, 14, 10, 11, 19, 10, 15, 12, 15, 12, 14, 8, 15, 9, 16, 16, 14, 17, 13, 13, 17, 8, 11, 14, 17, 13, 14, 11, 14, 15, 12, 11, 11, 10, 17, 9, 13, 15, 13, 12, 10, 11, 11, 11, 11, 10, 10, 17, 13, 10, 15, 10,
# 801     2:41:55 PM
# Name: Pickup - Time, Length: 21201, dtype: object

# %%
Train["Pickup - Time"] = heure(Train ['Pickup - Time'])
Test['Pickup - Time'] = heure(Test ['Pickup - Time'])

# %%
Train.dtypes
# Out:
# Age                               int64
# Average_Rating                  float64
# Destination Lat                 float64
# Destination Long                float64
# Distance (KM)                     int64
# No_Of_Orders                      int64
# Personal or Business             object
# Pickup - Time                     int64
# Pickup - Weekday (Mo = 1)         int64
# Pickup Lat                      float64
# Pickup Long                     float64
# Platform Type                     int64
# Precipitation in millimeters    float64
# Temperature                     float64
# distance_ors                    float64
# duration_ors                    float64
# Time from Pickup to Arrival       int64
# dtype: object

# %%
def dummy(dataset,columns):
 for c in columns:
   dum = pd.get_dummies(dataset[c],prefix=c,prefix_sep="_")
   dataset = pd.concat([dataset,dum], axis=1)
   del dataset[c]
 return dataset

# %%
print(Train.shape)
print(Test.shape)
# Out:
# (21201, 17)
# (7068, 16)

# %%
dummies_col = ["Platform Type","Personal or Business","Pickup - Weekday (Mo = 1)"]
Train = dummy(Train,dummies_col)
Test =dummy(Test,dummies_col)

# %%
print(Train.shape)
print(Test.shape)
# Out:
# (21201, 27)
# (7068, 26)

# %%
Train.describe()
# Out:
#                 Age  Average_Rating  Destination Lat  Destination Long  \
# count  21201.000000    21201.000000     21201.000000      21201.000000
# mean     984.742842       13.882520        -1.282581         36.811220
# std      646.652835        0.916071         0.034824          0.044721
# min       96.000000        0.000000        -1.430298         36.606594
# 25%      495.000000       13.600000        -1.301201         36.785661
# 50%      872.000000       14.000000        -1.284382         36.808002
# 75%     1236.000000       14.300000        -1.261177         36.829477
# max     3764.000000       15.200000        -1.030225         37.016779
#
#        Distance (KM)  No_Of_Orders  Pickup - Time    Pickup Lat   Pickup Long  \
# count   21201.000000  21201.000000   21201.000000  21201.000000  21201.000000
# mean        9.506533   1692.423706      12.873214     -1.281470     36.811264
# std         5.668963   1574.308302       2.551666      0.030507      0.037473
# min         1.000000      2.000000       0.000000     -1.438302     36.653621
# 25%         5.000000    557.000000      11.000000     -1.300921     36.784605
# 50%         8.000000   1212.000000      13.000000     -1.279395     36.807040
# 75%        13.000000   2311.000000      15.000000     -1.257147     36.829741
# max        49.000000   9756.000000      23.000000     -1.147170     36.991046
#
#        Precipitation in millimeters  ...  Platform Type_4  \
# count                  21201.000000  ...     21201.000000
# mean                       0.205839  ...         0.000943
# std                        3.029194  ...         0.030700
# min                        0.000000  ...         0.000000
# 25%                        0.000000  ...         0.000000
# 50%                        0.000000  ...         0.000000
# 75%                        0.000000  ...         0.000000
# max                       99.100000  ...         1.000000
#
#        Personal or Business_Business  Personal or Business_Personal  \
# count                   21201.000000                   21201.000000
# mean                        0.819961                       0.180039
# std                         0.384229                       0.384229
# min                         0.000000                       0.000000
# 25%                         1.000000                       0.000000
# 50%                         1.000000                       0.000000
# 75%                         1.000000                       0.000000
# max                         1.000000                       1.000000
#
#        Pickup - Weekday (Mo = 1)_1  Pickup - Weekday (Mo = 1)_2  \
# count                 21201.000000                 21201.000000
# mean                      0.178671                     0.186736
# std                       0.383085                     0.389709
# min                       0.000000                     0.000000
# 25%                       0.000000                     0.000000
# 50%                       0.000000                     0.000000
# 75%                       0.000000                     0.000000
# max                       1.000000                     1.000000
#
#        Pickup - Weekday (Mo = 1)_3  Pickup - Weekday (Mo = 1)_4  \
# count                 21201.000000                 21201.000000
# mean                      0.180322                     0.199472
# std                       0.384464                     0.399613
# min                       0.000000                     0.000000
# 25%                       0.000000                     0.000000
# 50%                       0.000000                     0.000000
# 75%                       0.000000                     0.000000
# max                       1.000000                     1.000000
#
#        Pickup - Weekday (Mo = 1)_5  Pickup - Weekday (Mo = 1)_6  \
# count                 21201.000000                 21201.000000
# mean                      0.188340                     0.057686
# std                       0.390993                     0.233154
# min                       0.000000                     0.000000
# 25%                       0.000000                     0.000000
# 50%                       0.000000                     0.000000
# 75%                       0.000000                     0.000000
# max                       1.000000                     1.000000
#
#        Pickup - Weekday (Mo = 1)_7
# count                 21201.000000
# mean                      0.008773
# std                       0.093256
# min                       0.000000
# 25%                       0.000000
# 50%                       0.000000
# 75%                       0.000000
# max                       1.000000
#
# [8 rows x 27 columns]

# %%
Train.corr()
# Out:
#                                     Age  Average_Rating  Destination Lat  \
# Age                            1.000000       -0.014348         0.009552
# Average_Rating                -0.014348        1.000000         0.030488
# Destination Lat                0.009552        0.030488         1.000000
# Destination Long              -0.018235        0.002017         0.046767
# Distance (KM)                  0.036239       -0.008200        -0.079366
# No_Of_Orders                   0.669036        0.051375        -0.001135
# Pickup - Time                 -0.001511       -0.003933         0.018985
# Pickup Lat                     0.002481        0.043610         0.114975
# Pickup Long                   -0.001656       -0.001885         0.014992
# Precipitation in millimeters   0.012079       -0.000432        -0.001703
# Temperature                   -0.037470       -0.024769         0.009236
# distance_ors                   0.019801       -0.012717        -0.086682
# duration_ors                   0.018691       -0.014956        -0.100600
# Time from Pickup to Arrival   -0.007969       -0.042559        -0.061872
# Platform Type_1                0.062826        0.012550        -0.008515
# Platform Type_2                0.041411        0.007610         0.007126
# Platform Type_3               -0.078672       -0.015150         0.002149
# Platform Type_4                0.010488        0.000083         0.010052
# Personal or Business_Business -0.071117       -0.016044         0.006672
# Personal or Business_Personal  0.071117        0.016044        -0.006672
# Pickup - Weekday (Mo = 1)_1    0.009234       -0.005092         0.007048
# Pickup - Weekday (Mo = 1)_2   -0.007640        0.009897         0.007509
# Pickup - Weekday (Mo = 1)_3    0.015558        0.001718        -0.005982
# Pickup - Weekday (Mo = 1)_4    0.004047        0.010002        -0.006686
# Pickup - Weekday (Mo = 1)_5   -0.005540       -0.014144        -0.011362
# Pickup - Weekday (Mo = 1)_6   -0.027755       -0.002103         0.008276
# Pickup - Weekday (Mo = 1)_7    0.005128       -0.005824         0.019927
#
#                                Destination Long  Distance (KM)  No_Of_Orders  \
# Age                                   -0.018235       0.036239      0.669036
# Average_Rating                         0.002017      -0.008200      0.051375
# Destination Lat                        0.046767      -0.079366     -0.001135
# Destination Long                       1.000000       0.135397     -0.013809
# Distance (KM)                          0.135397       1.000000      0.037186
# No_Of_Orders                          -0.013809       0.037186      1.000000
# Pickup - Time                         -0.002764      -0.036373     -0.007390
# Pickup Lat                             0.051399      -0.124338     -0.018190
# Pickup Long                            0.082803       0.178537      0.011274
# Precipitation in millimeters           0.006729      -0.001761      0.012714
# Temperature                            0.023421      -0.002090      0.030102
# distance_ors                           0.133044       0.850473      0.022505
# duration_ors                           0.128943       0.839828      0.021005
# Time from Pickup to Arrival            0.070425       0.580608     -0.041608
# Platform Type_1                       -0.029907       0.000620     -0.018629
# Platform Type_2                       -0.045283      -0.015312     -0.017924
# Platform Type_3                        0.052385       0.006788      0.026286
# Platform Type_4                       -0.003055       0.020021      0.001239
# Personal or Business_Business          0.063084       0.007177      0.029981
# Personal or Business_Personal         -0.063084      -0.007177     -0.029981
# Pickup - Weekday (Mo = 1)_1            0.006936       0.008455      0.010044
# Pickup - Weekday (Mo = 1)_2           -0.006776      -0.006477      0.005400
# Pickup - Weekday (Mo = 1)_3            0.002683       0.004816      0.013627
# Pickup - Weekday (Mo = 1)_4            0.002545      -0.015515     -0.000691
# Pickup - Weekday (Mo = 1)_5           -0.012797      -0.005056     -0.011322
# Pickup - Weekday (Mo = 1)_6            0.006439       0.011724     -0.029803
# Pickup - Weekday (Mo = 1)_7            0.015414       0.030853      0.004933
#
#                                Pickup - Time  Pickup Lat  Pickup Long  \
# Age                                -0.001511    0.002481    -0.001656
# Average_Rating                     -0.003933    0.043610    -0.001885
# Destination Lat                     0.018985    0.114975     0.014992
# Destination Long                   -0.002764    0.051399     0.082803
# Distance (KM)                      -0.036373   -0.124338     0.178537
# No_Of_Orders                       -0.007390   -0.018190     0.011274
# Pickup - Time                       1.000000    0.039430    -0.011040
# Pickup Lat                          0.039430    1.000000    -0.147629
# Pickup Long                        -0.011040   -0.147629     1.000000
# Precipitation in millimeters       -0.078653   -0.005395    -0.007141
# Temperature                         0.360985    0.015950     0.007824
# distance_ors                       -0.021792   -0.126746     0.131717
# duration_ors                       -0.020805   -0.145096     0.137837
# Time from Pickup to Arrival         0.010314   -0.053823     0.060285
# Platform Type_1                     0.020907    0.003526    -0.008288
# Platform Type_2                     0.009266   -0.006601    -0.037733
# Platform Type_3                    -0.023241    0.003643     0.028166
# Platform Type_4                     0.000323   -0.031689     0.013332
# Personal or Business_Business      -0.017269    0.022352     0.036729
# Personal or Business_Personal       0.017269   -0.022352    -0.036729
# Pickup - Weekday (Mo = 1)_1         0.001991   -0.002727    -0.000427
# Pickup - Weekday (Mo = 1)_2        -0.003418    0.004828    -0.009653
# Pickup - Weekday (Mo = 1)_3        -0.004342   -0.009185     0.003624
# Pickup - Weekday (Mo = 1)_4         0.007271    0.009309    -0.008813
# Pickup - Weekday (Mo = 1)_5         0.022895    0.007839    -0.000373
# Pickup - Weekday (Mo = 1)_6        -0.050421   -0.021099     0.033362
# Pickup - Weekday (Mo = 1)_7         0.022912    0.008891    -0.016928
#
#                                Precipitation in millimeters  ...  \
# Age                                                0.012079  ...
# Average_Rating                                    -0.000432  ...
# Destination Lat                                   -0.001703  ...
# Destination Long                                   0.006729  ...
# Distance (KM)                                     -0.001761  ...
# No_Of_Orders                                       0.012714  ...
# Pickup - Time                                     -0.078653  ...
# Pickup Lat                                        -0.005395  ...
# Pickup Long                                       -0.007141  ...
# Precipitation in millimeters                       1.000000  ...
# Temperature                                       -0.116503  ...
# distance_ors                                       0.000280  ...
# duration_ors                                      -0.000651  ...
# Time from Pickup to Arrival                        0.005495  ...
# Platform Type_1                                    0.007993  ...
# Platform Type_2                                    0.010766  ...
# Platform Type_3                                   -0.013018  ...
# Platform Type_4                                   -0.001429  ...
# Personal or Business_Business                     -0.008823  ...
# Personal or Business_Personal                      0.008823  ...
# Pickup - Weekday (Mo = 1)_1                       -0.024178  ...
# Pickup - Weekday (Mo = 1)_2                        0.077253  ...
# Pickup - Weekday (Mo = 1)_3                       -0.015736  ...
# Pickup - Weekday (Mo = 1)_4                       -0.015423  ...
# Pickup - Weekday (Mo = 1)_5                       -0.013167  ...
# Pickup - Weekday (Mo = 1)_6                       -0.012732  ...
# Pickup - Weekday (Mo = 1)_7                       -0.005508  ...
#
#                                Platform Type_4  Personal or Business_Business  \
# Age                                   0.010488                      -0.071117
# Average_Rating                        0.000083                      -0.016044
# Destination Lat                       0.010052                       0.006672
# Destination Long                     -0.003055                       0.063084
# Distance (KM)                         0.020021                       0.007177
# No_Of_Orders                          0.001239                       0.029981
# Pickup - Time                         0.000323                      -0.017269
# Pickup Lat                           -0.031689                       0.022352
# Pickup Long                           0.013332                       0.036729
# Precipitation in millimeters         -0.001429                      -0.008823
# Temperature                          -0.017148                       0.204049
# distance_ors                          0.011704                       0.023101
# duration_ors                          0.011674                       0.026135
# Time from Pickup to Arrival           0.003680                      -0.013354
# Platform Type_1                      -0.010315                      -0.587375
# Platform Type_2                      -0.006765                      -0.432980
# Platform Type_3                      -0.073600                       0.752879
# Platform Type_4                       1.000000                       0.014399
# Personal or Business_Business         0.014399                       1.000000
# Personal or Business_Personal        -0.014399                      -1.000000
# Pickup - Weekday (Mo = 1)_1           0.001711                      -0.005452
# Pickup - Weekday (Mo = 1)_2          -0.006839                       0.028595
# Pickup - Weekday (Mo = 1)_3           0.009566                       0.012864
# Pickup - Weekday (Mo = 1)_4           0.000041                       0.017014
# Pickup - Weekday (Mo = 1)_5          -0.003013                      -0.000975
# Pickup - Weekday (Mo = 1)_6          -0.001013                      -0.057294
# Pickup - Weekday (Mo = 1)_7          -0.002891                      -0.075712
#
#                                Personal or Business_Personal  \
# Age                                                 0.071117
# Average_Rating                                      0.016044
# Destination Lat                                    -0.006672
# Destination Long                                   -0.063084
# Distance (KM)                                      -0.007177
# No_Of_Orders                                       -0.029981
# Pickup - Time                                       0.017269
# Pickup Lat                                         -0.022352
# Pickup Long                                        -0.036729
# Precipitation in millimeters                        0.008823
# Temperature                                        -0.204049
# distance_ors                                       -0.023101
# duration_ors                                       -0.026135
# Time from Pickup to Arrival                         0.013354
# Platform Type_1                                     0.587375
# Platform Type_2                                     0.432980
# Platform Type_3                                    -0.752879
# Platform Type_4                                    -0.014399
# Personal or Business_Business                      -1.000000
# Personal or Business_Personal                       1.000000
# Pickup - Weekday (Mo = 1)_1                         0.005452
# Pickup - Weekday (Mo = 1)_2                        -0.028595
# Pickup - Weekday (Mo = 1)_3                        -0.012864
# Pickup - Weekday (Mo = 1)_4                        -0.017014
# Pickup - Weekday (Mo = 1)_5                         0.000975
# Pickup - Weekday (Mo = 1)_6                         0.057294
# Pickup - Weekday (Mo = 1)_7                         0.075712
#
#                                Pickup - Weekday (Mo = 1)_1  \
# Age                                               0.009234
# Average_Rating                                   -0.005092
# Destination Lat                                   0.007048
# Destination Long                                  0.006936
# Distance (KM)                                     0.008455
# No_Of_Orders                                      0.010044
# Pickup - Time                                     0.001991
# Pickup Lat                                       -0.002727
# Pickup Long                                      -0.000427
# Precipitation in millimeters                     -0.024178
# Temperature                                      -0.032204
# distance_ors                                      0.007739
# duration_ors                                      0.008021
# Time from Pickup to Arrival                      -0.028885
# Platform Type_1                                   0.003834
# Platform Type_2                                  -0.010026
# Platform Type_3                                   0.002520
# Platform Type_4                                   0.001711
# Personal or Business_Business                    -0.005452
# Personal or Business_Personal                     0.005452
# Pickup - Weekday (Mo = 1)_1                       1.000000
# Pickup - Weekday (Mo = 1)_2                      -0.223495
# Pickup - Weekday (Mo = 1)_3                      -0.218761
# Pickup - Weekday (Mo = 1)_4                      -0.232820
# Pickup - Weekday (Mo = 1)_5                      -0.224674
# Pickup - Weekday (Mo = 1)_6                      -0.115400
# Pickup - Weekday (Mo = 1)_7                      -0.043879
#
#                                Pickup - Weekday (Mo = 1)_2  \
# Age                                              -0.007640
# Average_Rating                                    0.009897
# Destination Lat                                   0.007509
# Destination Long                                 -0.006776
# Distance (KM)                                    -0.006477
# No_Of_Orders                                      0.005400
# Pickup - Time                                    -0.003418
# Pickup Lat                                        0.004828
# Pickup Long                                      -0.009653
# Precipitation in millimeters                      0.077253
# Temperature                                      -0.023550
# distance_ors                                     -0.003500
# duration_ors                                     -0.004466
# Time from Pickup to Arrival                       0.016140
# Platform Type_1                                  -0.033670
# Platform Type_2                                  -0.008648
# Platform Type_3                                   0.034268
# Platform Type_4                                  -0.006839
# Personal or Business_Business                     0.028595
# Personal or Business_Personal                    -0.028595
# Pickup - Weekday (Mo = 1)_1                      -0.223495
# Pickup - Weekday (Mo = 1)_2                       1.000000
# Pickup - Weekday (Mo = 1)_3                      -0.224751
# Pickup - Weekday (Mo = 1)_4                      -0.239195
# Pickup - Weekday (Mo = 1)_5                      -0.230825
# Pickup - Weekday (Mo = 1)_6                      -0.118559
# Pickup - Weekday (Mo = 1)_7                      -0.045081
#
#                                Pickup - Weekday (Mo = 1)_3  \
# Age                                               0.015558
# Average_Rating                                    0.001718
# Destination Lat                                  -0.005982
# Destination Long                                  0.002683
# Distance (KM)                                     0.004816
# No_Of_Orders                                      0.013627
# Pickup - Time                                    -0.004342
# Pickup Lat                                       -0.009185
# Pickup Long                                       0.003624
# Precipitation in millimeters                     -0.015736
# Temperature                                       0.020833
# distance_ors                                      0.003015
# duration_ors                                      0.003793
# Time from Pickup to Arrival                       0.007819
# Platform Type_1                                  -0.012668
# Platform Type_2                                  -0.008598
# Platform Type_3                                   0.015001
# Platform Type_4                                   0.009566
# Personal or Business_Business                     0.012864
# Personal or Business_Personal                    -0.012864
# Pickup - Weekday (Mo = 1)_1                      -0.218761
# Pickup - Weekday (Mo = 1)_2                      -0.224751
# Pickup - Weekday (Mo = 1)_3                       1.000000
# Pickup - Weekday (Mo = 1)_4                      -0.234129
# Pickup - Weekday (Mo = 1)_5                      -0.225937
# Pickup - Weekday (Mo = 1)_6                      -0.116048
# Pickup - Weekday (Mo = 1)_7                      -0.044126
#
#                                Pickup - Weekday (Mo = 1)_4  \
# Age                                               0.004047
# Average_Rating                                    0.010002
# Destination Lat                                  -0.006686
# Destination Long                                  0.002545
# Distance (KM)                                    -0.015515
# No_Of_Orders                                     -0.000691
# Pickup - Time                                     0.007271
# Pickup Lat                                        0.009309
# Pickup Long                                      -0.008813
# Precipitation in millimeters                     -0.015423
# Temperature                                       0.020619
# distance_ors                                     -0.014956
# duration_ors                                     -0.014198
# Time from Pickup to Arrival                      -0.000376
# Platform Type_1                                  -0.011059
# Platform Type_2                                  -0.017136
# Platform Type_3                                   0.019501
# Platform Type_4                                   0.000041
# Personal or Business_Business                     0.017014
# Personal or Business_Personal                    -0.017014
# Pickup - Weekday (Mo = 1)_1                      -0.232820
# Pickup - Weekday (Mo = 1)_2                      -0.239195
# Pickup - Weekday (Mo = 1)_3                      -0.234129
# Pickup - Weekday (Mo = 1)_4                       1.000000
# Pickup - Weekday (Mo = 1)_5                      -0.240457
# Pickup - Weekday (Mo = 1)_6                      -0.123506
# Pickup - Weekday (Mo = 1)_7                      -0.046962
#
#                                Pickup - Weekday (Mo = 1)_5  \
# Age                                              -0.005540
# Average_Rating                                   -0.014144
# Destination Lat                                  -0.011362
# Destination Long                                 -0.012797
# Distance (KM)                                    -0.005056
# No_Of_Orders                                     -0.011322
# Pickup - Time                                     0.022895
# Pickup Lat                                        0.007839
# Pickup Long                                      -0.000373
# Precipitation in millimeters                     -0.013167
# Temperature                                       0.034058
# distance_ors                                     -0.003509
# duration_ors                                     -0.003531
# Time from Pickup to Arrival                       0.018667
# Platform Type_1                                  -0.000146
# Platform Type_2                                   0.012311
# Platform Type_3                                  -0.006886
# Platform Type_4                                  -0.003013
# Personal or Business_Business                    -0.000975
# Personal or Business_Personal                     0.000975
# Pickup - Weekday (Mo = 1)_1                      -0.224674
# Pickup - Weekday (Mo = 1)_2                      -0.230825
# Pickup - Weekday (Mo = 1)_3                      -0.225937
# Pickup - Weekday (Mo = 1)_4                      -0.240457
# Pickup - Weekday (Mo = 1)_5                       1.000000
# Pickup - Weekday (Mo = 1)_6                      -0.119185
# Pickup - Weekday (Mo = 1)_7                      -0.045319
#
#                                Pickup - Weekday (Mo = 1)_6  \
# Age                                              -0.027755
# Average_Rating                                   -0.002103
# Destination Lat                                   0.008276
# Destination Long                                  0.006439
# Distance (KM)                                     0.011724
# No_Of_Orders                                     -0.029803
# Pickup - Time                                    -0.050421
# Pickup Lat                                       -0.021099
# Pickup Long                                       0.033362
# Precipitation in millimeters                     -0.012732
# Temperature                                      -0.029642
# distance_ors                                      0.009832
# duration_ors                                      0.009153
# Time from Pickup to Arrival                      -0.027878
# Platform Type_1                                   0.063135
# Platform Type_2                                   0.038991
# Platform Type_3                                  -0.076513
# Platform Type_4                                  -0.001013
# Personal or Business_Business                    -0.057294
# Personal or Business_Personal                     0.057294
# Pickup - Weekday (Mo = 1)_1                      -0.115400
# Pickup - Weekday (Mo = 1)_2                      -0.118559
# Pickup - Weekday (Mo = 1)_3                      -0.116048
# Pickup - Weekday (Mo = 1)_4                      -0.123506
# Pickup - Weekday (Mo = 1)_5                      -0.119185
# Pickup - Weekday (Mo = 1)_6                       1.000000
# Pickup - Weekday (Mo = 1)_7                      -0.023277
#
#                                Pickup - Weekday (Mo = 1)_7
# Age                                               0.005128
# Average_Rating                                   -0.005824
# Destination Lat                                   0.019927
# Destination Long                                  0.015414
# Distance (KM)                                     0.030853
# No_Of_Orders                                      0.004933
# Pickup - Time                                     0.022912
# Pickup Lat                                        0.008891
# Pickup Long                                      -0.016928
# Precipitation in millimeters                     -0.005508
# Temperature                                      -0.012225
# distance_ors                                      0.024629
# duration_ors                                      0.022836
# Time from Pickup to Arrival                       0.012018
# Platform Type_1                                   0.067338
# Platform Type_2                                   0.037103
# Platform Type_3                                  -0.078802
# Platform Type_4                                  -0.002891
# Personal or Business_Business                    -0.075712
# Personal or Business_Personal                     0.075712
# Pickup - Weekday (Mo = 1)_1                      -0.043879
# Pickup - Weekday (Mo = 1)_2                      -0.045081
# Pickup - Weekday (Mo = 1)_3                      -0.044126
# Pickup - Weekday (Mo = 1)_4                      -0.046962
# Pickup - Weekday (Mo = 1)_5                      -0.045319
# Pickup - Weekday (Mo = 1)_6                      -0.023277
# Pickup - Weekday (Mo = 1)_7                       1.000000
#
# [27 rows x 27 columns]

# %%
y_train = Train['Time from Pickup to Arrival']
c = list(set(Train.columns) - {"Time from Pickup to Arrival"})
X_train = Train[sorted(c)]
X_test = Test[sorted(c)]

# %% [markdown]
# # BON MODEL DE L'INSTANT with precipitation, average_of_rating, duration_ors & distance_ors

# %%
# !pip install lightgbm
# Out:
# Requirement already satisfied: lightgbm in /home/moussa/snap/jupyter/common/lib/python3.7/site-packages (2.3.0)
# Requirement already satisfied: numpy in /home/moussa/snap/jupyter/common/lib/python3.7/site-packages (from lightgbm) (1.17.3)
# Requirement already satisfied: scipy in /home/moussa/snap/jupyter/common/lib/python3.7/site-packages (from lightgbm) (1.3.1)
# Requirement already satisfied: scikit-learn in /home/moussa/snap/jupyter/common/lib/python3.7/site-packages (from lightgbm) (0.21.3)
# Requirement already satisfied: joblib>=0.11 in /home/moussa/snap/jupyter/common/lib/python3.7/site-packages (from scikit-learn->lightgbm) (0.14.0)

# %%
from lightgbm import LGBMRegressor

# %%
lgbm = LGBMRegressor(
    num_leaves=65,
    max_depth=5,
    learning_rate=0.06,
    n_estimators=500
)
# Out:
# LGBMRegressor(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#               importance_type='split', learning_rate=0.06, max_depth=5,
#               min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#               n_estimators=500, n_jobs=-1, num_leaves=65, objective=None,
#               random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#               subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
lgbm.fit(X_train,y_train)
print("score:",lgbm.score(X_train,y_train))

X2 = sm.add_constant(X_train)
est = sm.OLS(y_train, X2)
est2 = est.fit()
print(est2.summary())

# %%
y_pred_ = lgbm.predict(X_test)

# %%
sp["Time from Pickup to Arrival"] = y_pred_
sp.to_csv("zindi_30000.csv",index=False) # 727.863210902153
